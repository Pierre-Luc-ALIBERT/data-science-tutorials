# %% [markdown]
# # Introduction to pandas, visualizing Titanic
#
# ## Master 2 TSE
#
# #### Raphaël Sourty

# %%
import pandas as pd

# %% [markdown]
# #### You can download the data here: https://www.kaggle.com/c/titanic/data

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# | Variable 	| Definition                                 	| Key                                            	|
# |----------	|--------------------------------------------	|------------------------------------------------	|
# | survival 	| Survival                                   	| 0 = No, 1 = Yes                                	|
# | pclass   	| Ticket class                               	| 1 = 1st, 2 = 2nd, 3 = 3rd                      	|
# | sex      	| Sex                                        	|                                                	|
# | Age      	| Age in years                               	|                                                	|
# | sibsp    	| # of siblings / spouses aboard the Titanic 	|                                                	|
# | parch    	| # of parents / children aboard the Titanic 	|                                                	|
# | ticket   	| Ticket number                              	|                                                	|
# | fare     	| Passenger fare                             	|                                                	|
# | cabin    	| Cabin number                               	|                                                	|
# | embarked 	| Port of Embarkation                        	| C = Cherbourg, Q = Queenstown, S = Southampton 	|

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Who are the survivors of the Titanic?

# %% [markdown]
# #### Survival rate

# %%
df.groupby('Survived')['PassengerId'].agg(['count'])
# Out:
#           count
# Survived
# 0           549
# 1           342

# %%
df.groupby('Survived')['PassengerId'].agg(
    ['count']
).reset_index().plot(x='Survived', y='count', kind = 'bar', figsize = (8, 8))

# %% [markdown]
# #### Survival rate depending on genre

# %%
df.groupby(
    ['Survived', 'Sex']
)['PassengerId'].agg(['count'])
# Out:
#                  count
# Survived Sex
# 0        female     81
#          male      468
# 1        female    233
#          male      109

# %%
df.groupby(
    ['Survived', 'Sex']
)['PassengerId'].agg(['count']).unstack()
# Out:
#           count
# Sex      female male
# Survived
# 0            81  468
# 1           233  109

# %%
df.groupby(
    ['Survived', 'Sex']
)['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))

# %% [markdown]
# #### Survival rate depending on Ticket class

# %%
df.groupby(['Survived', 'Pclass'])['PassengerId'].agg(
    ['count']
)
# Out:
#                  count
# Survived Pclass
# 0        1          80
#          2          97
#          3         372
# 1        1         136
#          2          87
#          3         119

# %%
df.groupby(['Survived', 'Pclass'])['PassengerId'].count().unstack()
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
df.groupby(
    ['Survived', 'Pclass']
)['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))

# %% [markdown]
# #### Survival rate depending on Age

# %%
df['generation'] = pd.cut(df['Age'], 8)

# %%
# [(0.34, 10.368] 
# (10.368, 20.315] 
# (20.315, 30.263] 
# (30.263, 40.21] 
# (40.21, 50.158] 
# (50.158, 60.105] 
# (60.105, 70.052] 
# (70.052, 80.0]]

pd.cut(df['Age'], 8)
# Out:
# 0      (20.315, 30.263]
# 1       (30.263, 40.21]
# 2      (20.315, 30.263]
# 3       (30.263, 40.21]
# 4       (30.263, 40.21]
#              ...
# 886    (20.315, 30.263]
# 887    (10.368, 20.315]
# 888                 NaN
# 889    (20.315, 30.263]
# 890     (30.263, 40.21]
# Name: Age, Length: 891, dtype: category
# Categories (8, interval[float64]): [(0.34, 10.368] < (10.368, 20.315] < (20.315, 30.263] < (30.263, 40.21] < (40.21, 50.158] < (50.158, 60.105] < (60.105, 70.052] < (70.052, 80.0]]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked        generation
# 0      0         A/5 21171   7.2500   NaN        S  (20.315, 30.263]
# 1      0          PC 17599  71.2833   C85        C   (30.263, 40.21]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  (20.315, 30.263]
# 3      0            113803  53.1000  C123        S   (30.263, 40.21]
# 4      0            373450   8.0500   NaN        S   (30.263, 40.21]

# %%
df.groupby(
    ['Survived', 'generation']
)['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))

# %% [markdown]
# #### Survival rate depending on Fare

# %%
df['fare_category'] = pd.cut(df['Fare'], 12)

# %%
pd.cut(df['Fare'], 10)
# Out:
# 0       (-0.512, 51.233]
# 1      (51.233, 102.466]
# 2       (-0.512, 51.233]
# 3      (51.233, 102.466]
# 4       (-0.512, 51.233]
#              ...
# 886     (-0.512, 51.233]
# 887     (-0.512, 51.233]
# 888     (-0.512, 51.233]
# 889     (-0.512, 51.233]
# 890     (-0.512, 51.233]
# Name: Fare, Length: 891, dtype: category
# Categories (10, interval[float64]): [(-0.512, 51.233] < (51.233, 102.466] < (102.466, 153.699] < (153.699, 204.932] ... (307.398, 358.63] < (358.63, 409.863] < (409.863, 461.096] < (461.096, 512.329]]

# %%
df.groupby(
    ['Survived', 'fare_category']
)['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))

# %% [markdown]
# #### What about correlations?

# %%
df[['Survived', 'Pclass', 'Age', 'Fare', 'SibSp', 'Parch']].corr()
# Out:
#           Survived    Pclass       Age      Fare     SibSp     Parch
# Survived  1.000000 -0.338481 -0.077221  0.257307 -0.035322  0.081629
# Pclass   -0.338481  1.000000 -0.369226 -0.549500  0.083081  0.018443
# Age      -0.077221 -0.369226  1.000000  0.096067 -0.308247 -0.189119
# Fare      0.257307 -0.549500  0.096067  1.000000  0.159651  0.216225
# SibSp    -0.035322  0.083081 -0.308247  0.159651  1.000000  0.414838
# Parch     0.081629  0.018443 -0.189119  0.216225  0.414838  1.000000

# %%
df[['Survived', 'Pclass', 'Age', 'Fare', 'SibSp', 'Parch']].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col2 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col3 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col4 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col4 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col5 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col3 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col0 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col2 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col4 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row3_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col1 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col3 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row4_col5 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col1 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col2 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col3 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col4 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_c6b5e25c_4930_11ed_9907_b6646dd092c1row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>        <th class="col_heading level0 col1" >Pclass</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >Fare</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1level0_row0" class="row_heading level0 row0" >Survived</th>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col1" class="data row0 col1" >-0.338481</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col2" class="data row0 col2" >-0.0772211</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col3" class="data row0 col3" >0.257307</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col4" class="data row0 col4" >-0.0353225</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row0_col5" class="data row0 col5" >0.0816294</td>
#             </tr>
#             <tr>
#                         <th id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1level0_row1" class="row_heading level0 row1" >Pclass</th>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col0" class="data row1 col0" >-0.338481</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col2" class="data row1 col2" >-0.369226</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col3" class="data row1 col3" >-0.5495</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col4" class="data row1 col4" >0.0830814</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row1_col5" class="data row1 col5" >0.0184427</td>
#             </tr>
#             <tr>
#                         <th id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1level0_row2" class="row_heading level0 row2" >Age</th>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col0" class="data row2 col0" >-0.0772211</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col1" class="data row2 col1" >-0.369226</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col3" class="data row2 col3" >0.0960667</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col4" class="data row2 col4" >-0.308247</td>
#                         <td id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1row2_col5" class="data row2 col5" >-0.189119</td>
#             </tr>
#             <tr>
#                         <th id="T_c6b5e25c_4930_11ed_9907_b6646dd092c1l

# %% [markdown]
# ## Questions:

# %% [markdown]
# ##### Cabins on the port side have an even number and cabins on the starboard side have an odd number.
#
# #### For example, cabin B57 is located on the starboard side.
#
# #### Which side of the boat is better to be on?
#
#
# #### The deck number of the boat is indicated on the ticket. Cabin B57 is located on deck B. Which deck is best to be on?
#
# #### Where is the best place to be on the boat in general?
#
# #### Is there a link between the number of parents/family on the boat and chances of survival?

# %%
df.columns.append("Odd_Cabin")

for i in range(len(df)):
    if type(df.iloc[i]["Cabin"]) == str:
        if len(df.iloc[i]["Cabin"])>1:
            df["Odd_Cabin"][i] = int(df.iloc[i]["Cabin"][-1])%2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-5121d7a13d17> in <module>
# ----> 1 df.columns.append("Odd_Cabin")
#       2
#       3 for i in range(len(df)):
#       4     if type(df.iloc[i]["Cabin"]) == str:
#       5         if len(df.iloc[i]["Cabin"])>1:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in append(self, other)
#    4330         for obj in to_concat:
#    4331             if not isinstance(obj, Index):
# -> 4332                 raise TypeError("all inputs must be Index")
#    4333
#    4334         names = {obj.name for obj in to_concat}
#
# TypeError: all inputs must be Index

# %%
df.groupby(
    ['Survived', int(df["Cabin"][-1])%2]
)['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-118a013259d3> in <module>
#       1 df.groupby(
# ----> 2     ['Survived', int(df["Cabin"][-1])%2]
#       3 )['PassengerId'].count().unstack().plot(kind ='bar', figsize = (10, 10))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1

# %%
df[:16]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch            Ticket     Fare Cabin Embarked        generation  \
# 0       0         A/5 21171   7.2500   NaN        S  (20.315, 30.263]
# 1       0          PC 17599  71.2833   C85        C   (30.263, 40.21]
# 2       0  STON/O2. 3101282   7.9250   NaN        S  (20.315, 30.263]
# 3       0            113803  53.1000  C123        S   (30.263, 40.21]
# 4       0            373450   8.0500   NaN        S   (30.263, 40.21]
# 5       0            330877   8.4583   NaN        Q               NaN
# 6       0             17463  51.8625   E46        S  (50.158, 60.105]
# 7       1            349909  21.0750   NaN        S    (0.34, 10.368]
# 8       2            347742  11.1333   NaN        S  (20.315, 30.263]
# 9       0            237736  30.0708   NaN        C  (10.368, 20.315]
# 10      1           PP 9549  16.7000    G6        S    (0.34, 10.368]
# 11      0            113783  26.5500  C103        S  (50.158, 60.105]
# 12      0         A/5. 2151   8.0500   NaN        S  (10.368, 20.315]
# 13      5            347082  31.2750   NaN        S   (30.263, 40.21]
# 14      0            350406   7.8542   NaN        S  (10.368, 20.315]
# 15      0            248706  16.0000   NaN        S  (50.158, 60.105]
#
#        fare_category  Odd_Cabin
# 0   (-0.512, 42.694]          1
# 1   (42.694, 85.388]          1
# 2   (-0.512, 42.694]          1
# 3   (42.694, 85.388]          1
# 4   (-0.512, 42.694]          1
# 5   (-0.512, 42.694]          1
# 6   (42.694, 85.388]          0
# 7   (-0.512, 42.694]          1
# 8   (-0.512, 42.694]          1
# 9   (-0.512, 42.694]          1
# 10  (-0.512, 42.694]          0
# 11  (-0.512, 42.694]          1
# 12  (-0.512, 42.694]          1
# 13  (-0.512, 42.694]          1
# 14  (-0.512, 42.694]          1
# 15  (-0.512, 42.694]          1

# %% [markdown]
# #### What is the typical profile of the person who will survive the shipwreck?
#
# #### What is the typical profile of the person who will not survive the shipwreck?
